# %% [markdown]
# The avearge starting salary of MBA graduates in US is provided in the file. Use the variables below to pedict the Avg Starting salary.
#
# 1) Train a decision tree by dropping the rows with missing values<br>
# 2) Impute the missing values in each column using KNN imputer, and then train a model<br>
# 3) Compare the score of both the above models. Use 5 fold CV score in both cases, with same model hyper-parameters (depth, etc)

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split, GridSearchCV

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
# Load data
salary = pd.read_excel('C:/Users/Karthik.Iyer/Downloads/AccelerateAI/Tree-Based-Models-main/08_MBA_Starting_Salary.xlsx', sheet_name='MBA Data')
salary.head()
# Out:
#   Fulltime Business Week Ranking                 School Name          State  \
# 0                              1       University of Chicago       Illinois
# 1                              2          Harvard University  Massachusetts
# 2                              3     Northwestern University       Illinois
# 3                              4  University of Pennsylvania   Pennsylvania
# 4                              5      University of Michigan       Michigan
#
#       Type  Enrollment  Avg GMAT  Resident Tuition, Fees  Pct International  \
# 0  Private        1144     713.0                 97165.0               35.0
# 1  Private        1801     720.0                101660.0               33.0
# 2  Private        1200     711.0                 93918.0               34.0
# 3  Private        1651     714.0                104410.0               44.0
# 4   Public         898     706.0                 80879.0               27.0
#
#    Pct Female  Pct Asian American  Pct Minority  Pct with job offers  \
# 0        35.0                16.0           7.0                 92.0
# 1        38.0                 NaN           NaN                 94.0
# 2        36.0                25.0          13.0                 95.0
# 3        36.0                 7.8           9.0                 89.0
# 4        34.0                21.0          13.0                 89.0
#
#    Avg starting base salary
# 0                  107091.0
# 1                  124378.0
# 2                  108064.0
# 3                  112186.0
# 4                  103608.0

# %%
# Check shape
salary.shape
# Out:
# (70, 13)

# %%
# Check info
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Fulltime Business Week Ranking  70 non-null     object
#  1   School Name                     70 non-null     object
#  2   State                           70 non-null     object
#  3   Type                            70 non-null     object
#  4   Enrollment                      70 non-null     int64
#  5   Avg GMAT                        67 non-null     float64
#  6   Resident Tuition, Fees          68 non-null     float64
#  7   Pct International               68 non-null     float64
#  8   Pct Female                      68 non-null     float64
#  9   Pct Asian American              63 non-null     float64
#  10  Pct Minority                    66 non-null     float64
#  11  Pct with job offers             67 non-null     float64
#  12  Avg starting base salary        67 non-null     float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 7.2+ KB

# %%
# Check missing values
salary.isna().sum()
# Out:
# Fulltime Business Week Ranking    0
# School Name                       0
# State                             0
# Type                              0
# Enrollment                        0
# Avg GMAT                          3
# Resident Tuition, Fees            2
# Pct International                 2
# Pct Female                        2
# Pct Asian American                7
# Pct Minority                      4
# Pct with job offers               3
# Avg starting base salary          3
# dtype: int64

# %%
# Lets drop Fulltime Business Week Ranking and School Name
salary.drop(['Fulltime Business Week Ranking', 'School Name'], axis=1, inplace=True)

# %%
# Lets drop missing values
salary_no_mv = salary.dropna()

# %%
# Check missing values again
salary_no_mv.isna().sum()
# Out:
# State                       0
# Type                        0
# Enrollment                  0
# Avg GMAT                    0
# Resident Tuition, Fees      0
# Pct International           0
# Pct Female                  0
# Pct Asian American          0
# Pct Minority                0
# Pct with job offers         0
# Avg starting base salary    0
# dtype: int64

# %%
# Check shape
salary_no_mv.shape
# Out:
# (60, 11)

# %%
# Convert State and Type into dummies
salary_no_mv_onehot = pd.get_dummies(salary_no_mv, columns=['State','Type'])
salary_no_mv_onehot.sample(5)
# Out:
#     Enrollment  Avg GMAT  Resident Tuition, Fees  Pct International  \
# 69         149     629.0                 70600.0               15.0
# 40         204     675.0                 55629.0               40.0
# 55         160     643.0                 45061.0               27.0
# 28         156     681.0                 17816.0               19.0
# 31         387     630.0                 72184.0               41.0
#
#     Pct Female  Pct Asian American  Pct Minority  Pct with job offers  \
# 69        33.0                 8.0           8.0                 82.0
# 40        37.0                18.0           1.0                 62.0
# 55        38.0                19.0           9.0                 62.0
# 28        27.0                 7.0           5.0                 98.0
# 31        37.0                14.0          11.0                 62.0
#
#     Avg starting base salary  State_Arizona  State_California  \
# 69                   79392.0              0                 0
# 40                   81500.0              0                 1
# 55                   83092.0              0                 0
# 28                   93403.0              0                 0
# 31                   92296.0              0                 0
#
#     State_Connecticut  State_Florida  State_Georgia  State_Illinois  \
# 69                  0              0              0               0
# 40                  0              0              0               0
# 55                  0              0              0               0
# 28                  0              0              1               0
# 31                  0              0              0               0
#
#     State_Indiana  State_Iowa  State_Louisiana  State_Maryland  \
# 69              0           0                0               0
# 40              0           0                0               0
# 55              0           0                0               0
# 28              0           0                0               0
# 31              0           0                0               0
#
#     State_Massachusetts  State_Michigan  State_Minnesota  State_Missouri  \
# 69                    0               0                0               0
# 40                    0               0                0               0
# 55                    0               0                0               0
# 28                    0               0                0               0
# 31                    1               0                0               0
#
#     State_New Hampshire  State_New Jersey  State_New York  \
# 69                    0                 0               0
# 40                    0                 0               0
# 55                    0                 1               0
# 28                    0                 0               0
# 31                    0                 0               0
#
#     State_North Carolina  State_Ohio  State_Pennsylvania  State_Tennessee  \
# 69                     1           0                   0                0
# 40                     0           0                   0                0
# 55                     0           0                   0                0
# 28                     0           0                   0                0
# 31                     0           0                   0                0
#
#     State_Texas  State_Virginia  State_Washington  State_Washington D.C.  \
# 69            0               0                 0                      0
# 40            0               0                 0                      0
# 55            0               0                 0                      0
# 28            0               0                 0                      0
# 31            0               0                 0                      0
#
#     State_Wisconsin  Type_Private  Type_Public
# 69                0             1            0
# 40                0             0            1
# 55                0             1            0
# 28                0             0            1
# 31                0             1            0

# %%
salary_no_mv_onehot.shape
# Out:
# (60, 37)

# %%
# Lets fit the decision tree without removing missing values
X = salary_no_mv_onehot.drop('Avg starting base salary', axis=1)
y = salary_no_mv_onehot['Avg starting base salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

params = {'max_depth' : [2,3,5,7,9,11],
          'min_samples_split' : [5,10,15,20,25,30,35,40],
          'min_samples_leaf' : [5,10,15,20,25,30,35,40]}

clf_gs = GridSearchCV(DecisionTreeRegressor(), cv=5, param_grid=params)

clf_gs.fit(X_train, y_train)

clf_gs.best_params_, clf_gs.best_score_
# Out:
# ({'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 25},
#  0.13635884252885297)

# %%
clf_gs.score(X_test, y_test)
# Out:
# 0.4014671557353948

# %% [markdown]
# **Only about 40% r2 score is obtained in case of excluding the missing rows from the dataset**

# %%
# Lets check missing values
salary.isna().sum()
# Out:
# State                       0
# Type                        0
# Enrollment                  0
# Avg GMAT                    3
# Resident Tuition, Fees      2
# Pct International           2
# Pct Female                  2
# Pct Asian American          7
# Pct Minority                4
# Pct with job offers         3
# Avg starting base salary    3
# dtype: int64

# %%
# Lets impute missing values using KNN imputer
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2)

# Convert State and Type into dummies
salary_onehot = pd.get_dummies(salary, columns=['State','Type'])

var_list = ['Avg GMAT','Resident Tuition, Fees','Pct International','Pct Female',
            'Pct Asian American','Pct Minority','Pct with job offers','Avg starting base salary']

salary_onehot_imputed = imputer.fit_transform(salary_onehot[var_list])

# %%
salary_onehot.sample(4)
# Out:
#     Enrollment  Avg GMAT  Resident Tuition, Fees  Pct International  \
# 66         199     631.0                 68626.0               32.0
# 27         294     681.0                 83172.0               34.0
# 41         119     627.0                 21188.0               38.0
# 2         1200     711.0                 93918.0               34.0
#
#     Pct Female  Pct Asian American  Pct Minority  Pct with job offers  \
# 66        36.0                19.0          21.0                 49.0
# 27        37.0                 7.0          12.0                 81.0
# 41        25.0                 5.0           9.0                 57.0
# 2         36.0                25.0          13.0                 95.0
#
#     Avg starting base salary  State_Arizona  State_California  State_Colorado  \
# 66                   62567.0              0                 0               0
# 27                   90775.0              0                 0               0
# 41                   95120.0              0                 0               0
# 2                   108064.0              0                 0               0
#
#     State_Connecticut  State_Florida  State_Georgia  State_Illinois  \
# 66                  0              1              0               0
# 27                  0              0              0               0
# 41                  1              0              0               0
# 2                   0              0              0               1
#
#     State_Indiana  State_Iowa  State_Louisiana  State_Maryland  \
# 66              0           0                0               0
# 27              0           0                0               0
# 41              0           0                0               0
# 2               0           0                0               0
#
#     State_Massachusetts  State_Michigan  State_Minnesota  State_Missouri  \
# 66                    0               0                0               0
# 27                    0               0                0               1
# 41                    0               0                0               0
# 2                     0               0                0               0
#
#     State_New Hampshire  State_New Jersey  State_New York  \
# 66                    0                 0               0
# 27                    0                 0               0
# 41                    0                 0               0
# 2                     0                 0               0
#
#     State_North Carolina  State_Ohio  State_Pennsylvania  State_Tennessee  \
# 66                     0           0                   0                0
# 27                     0           0                   0                0
# 41                     0           0                   0                0
# 2                      0           0                   0                0
#
#     State_Texas  State_Utah  State_Virginia  State_Washington  \
# 66            0           0               0                 0
# 27            0           0               0                 0
# 41            0           0               0                 0
# 2             0           0               0                 0
#
#     State_Washington D.C.  State_Wisconsin  Type_Private  Type_Public
# 66                      0                0             1            0
# 27                      0                0             1            0
# 41                      0                0             0            1
# 2                       0                0             1            0

# %%
salary_onehot_imputed
# Out:
#         6.00000000e+00, 9.00000000e+00, 8.40000000e+01, 8.86260000e+04],
#        [6.29000000e+02, 7.06000000e+04, 1.50000000e+01, 3.30000000e+01,
#         8.00000000e+00, 8.00000000e+00, 8.20000000e+01, 7.93920000e+04]])

# %%
# Check missing values
salary_onehot_imputed = pd.DataFrame(salary_onehot_imputed, columns=salary_onehot[var_list].columns)
salary_onehot_imputed.isna().sum()
# Out:
# Avg GMAT                    0
# Resident Tuition, Fees      0
# Pct International           0
# Pct Female                  0
# Pct Asian American          0
# Pct Minority                0
# Pct with job offers         0
# Avg starting base salary    0
# dtype: int64

# %%
# Merge with the rest of the dataframe
salary_df = pd.concat([salary_onehot['Enrollment'], salary_onehot_imputed, salary_onehot.drop(['Enrollment'] + var_list, axis=1)], axis=1)

# %%
# Lets check if there are any missing values
salary_df.isna().sum().sum()
# Out:
# 0

# %%
# Lets fit the decision tree without removing missing values
X = salary_df.drop('Avg starting base salary', axis=1)
y = salary_df['Avg starting base salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

params = {'max_depth' : [2,3,5,7,9,11],
          'min_samples_split' : [5,10,15,20,25,30,35,40],
          'min_samples_leaf' : [5,10,15,20,25,30,35,40]}

clf_gs = GridSearchCV(DecisionTreeRegressor(), cv=5, param_grid=params)

clf_gs.fit(X_train, y_train)

clf_gs.best_params_, clf_gs.best_score_
# Out:
# ({'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 5},
#  0.14760061591587892)

# %%
clf_gs.score(X_test, y_test)
# Out:
# 0.7675282259192849

# %% [markdown]
# **Keeping all the hyperparameters same, it can be seen that after using KNN imputation to handle missing values, the r2 score is much higher with value 76%**

# %%
# What if we increase the value of neighbours to 3 in KNN imputation
# Lets impute missing values using KNN imputer
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=3)

# Convert State and Type into dummies
salary_onehot = pd.get_dummies(salary, columns=['State','Type'])

var_list = ['Avg GMAT','Resident Tuition, Fees','Pct International','Pct Female',
            'Pct Asian American','Pct Minority','Pct with job offers','Avg starting base salary']

salary_onehot_imputed = imputer.fit_transform(salary_onehot[var_list])

# %%
# Convert into dataframe
salary_onehot_imputed = pd.DataFrame(salary_onehot_imputed, columns=salary_onehot[var_list].columns)

# %%
# Merge with the rest of the dataframe
salary_df = pd.concat([salary_onehot['Enrollment'], salary_onehot_imputed, salary_onehot.drop(['Enrollment'] + var_list, axis=1)], axis=1)

# %%
# Lets fit the decision tree without removing missing values
X = salary_df.drop('Avg starting base salary', axis=1)
y = salary_df['Avg starting base salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

params = {'max_depth' : [2,3,5,7,9,11],
          'min_samples_split' : [5,10,15,20,25,30,35,40],
          'min_samples_leaf' : [5,10,15,20,25,30,35,40]}

clf_gs = GridSearchCV(DecisionTreeRegressor(), cv=5, param_grid=params)

clf_gs.fit(X_train, y_train)

clf_gs.best_params_, clf_gs.best_score_
# Out:
# ({'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 5},
#  0.15447590711518622)

# %%
clf_gs.score(X_test, y_test)
# Out:
# 0.714707872544619

# %% [markdown]
# **The score did not improve with n_neighbors=3. So lets use n_neighbors=2 only**
