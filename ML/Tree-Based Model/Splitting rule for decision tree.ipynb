# %% [markdown]
# Consider the following data. What could be the splitting rule (on F1 or F2) for the following?

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import tree

# %%
# Laod data
d1 = {'F1':[4,6,9,1,7,5], 'F2':[1,6,5,2,3,4], 'Outcome':[0,0,1,0,1,1]}
df = pd.DataFrame(d1)
df
# Out:
#    F1  F2  Outcome
# 0   4   1        0
# 1   6   6        0
# 2   9   5        1
# 3   1   2        0
# 4   7   3        1
# 5   5   4        1

# %%
# Prepare X and y
X = df[['F1','F2']]
y = df['Outcome']

# %%
# ID3
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf = clf.fit(X,y)

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(clf)
[...]
# Out:
# [Ellipsis]

# %% [markdown]
# Splitting Criteria:
#
# F1 <= 4.5 OR F2 <= 5.5
